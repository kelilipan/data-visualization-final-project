# %%
from bokeh.io import curdoc, output_notebook
from bokeh.models.tools import HoverTool
from bokeh.models import DateRangeSlider,  ColumnDataSource, PreText, Select, Range1d, RadioButtonGroup, Div, CustomJS, Button
from bokeh.plotting import figure, output_file, show
from bokeh.layouts import column, row
import bokeh
import pandas as pd
import numpy as np
from os.path import dirname, join
# import data
df_confirmed = pd.read_csv('data/confirmed.csv',parse_dates=['date'])
df_death = pd.read_csv('data/death.csv',parse_dates=['date'])
df_recovered = pd.read_csv('data/recovered.csv',parse_dates=['date'])
df_confirmed.drop("Unnamed: 0", axis=1, inplace=True)
df_death.drop("Unnamed: 0", axis=1, inplace=True)
df_recovered.drop("Unnamed: 0" ,axis=1, inplace=True)
regions_death = df_death.columns[0:-1]
regions_confirmed = df_confirmed.columns[0:-1]
regions_recovered = df_recovered.columns[0:-1]

# %%
regions_death[78]
# Out:
# 'Indonesia'

# %%
dict(df_death.iloc[-1,])
# Out:
# {'Afghanistan': 40,
#  'Albania': 27,
#  'Algeria': 402,
#  'Andorra': 37,
#  'Angola': 2,
#  'Antigua and Barbuda': 3,
#  'Argentina': 152,
#  'Armenia': 24,
#  'Australia': 64,
#  'Austria': 510,
#  'Azerbaijan': 20,
#  'Bahamas': 9,
#  'Bahrain': 7,
#  'Bangladesh': 120,
#  'Barbados': 5,
#  'Belarus': 58,
#  'Belgium': 6262,
#  'Belize': 2,
#  'Benin': 1,
#  'Bhutan': 0,
#  'Bolivia': 37,
#  'Bosnia and Herzegovina': 53,
#  'Botswana': 1,
#  'Brazil': 2906,
#  'Brunei': 1,
#  'Bulgaria': 49,
#  'Burkina Faso': 39,
#  'Burma': 5,
#  'Burundi': 1,
#  'Cabo Verde': 1,
#  'Cambodia': 0,
#  'Cameroon': 43,
#  'Canada': 2009,
#  'Central African Republic': 0,
#  'Chad': 0,
#  'Chile': 160,
#  'China': 4630,
#  'Colombia': 206,
#  'Congo': 31,
#  'Costa Rica': 6,
#  "Cote d'Ivoire": 14,
#  'Croatia': 48,
#  'Cuba': 40,
#  'Cyprus': 13,
#  'Czechia': 208,
#  'Denmark': 384,
#  'Diamond Princess': 13,
#  'Djibouti': 2,
#  'Dominica': 0,
#  'Dominican Republic': 260,
#  'Ecuador': 537,
#  'Egypt': 276,
#  'El Salvador': 7,
#  'Equatorial Guinea': 1,
#  'Eritrea': 0,
#  'Estonia': 44,
#  'Eswatini': 1,
#  'Ethiopia': 3,
#  'Fiji': 0,
#  'Finland': 149,
#  'France': 21372,
#  'Gabon': 1,
#  'Gambia': 1,
#  'Georgia': 5,
#  'Germany': 5279,
#  'Ghana': 9,
#  'Greece': 121,
#  'Grenada': 0,
#  'Guatemala': 8,
#  'Guinea': 6,
#  'Guinea-Bissau': 0,
#  'Guyana': 7,
#  'Haiti': 4,
#  'Holy See': 0,
#  'Honduras': 46,
#  'Hungary': 225,
#  'Iceland': 10,
#  'India': 681,
#  'Indonesia': 635,
#  'Iran': 5391,
#  'Iraq': 83,
#  'Ireland': 769,
#  'Israel': 189,
#  'Italy': 25085,
#  'Jamaica': 6,
#  'Japan': 281,
#  'Jordan': 7,
#  'Kazakhstan': 19,
#  'Kenya': 14,
#  'Korea, South': 238,
#  'Kosovo': 12,
#  'Kuwait': 13,
#  'Kyrgyzstan': 7,
#  'Laos': 0,
#  'Latvia': 11,
#  'Lebanon': 22,
#  'Liberia': 8,
#  'Libya': 1,
#  'Liechtenstein': 1,
#  'Lithuania': 38,
#  'Luxembourg': 80,
#  'MS Zaandam': 2,
#  'Madagascar': 0,
#  'Malawi': 3,
#  'Malaysia': 93,
#  'Maldives': 0,
#  'Mali': 17,
#  'Malta': 3,
#  'Mauritania': 1,
#  'Mauritius': 9,
#  'Mexico': 857,
#  'Moldova': 75,
#  'Monaco': 3,
#  'Mongolia': 0,
#  'Montenegro': 5,
#  'Morocco': 149,
#  'Mozambique': 0,
#  'Namibia': 0,
#  'Nepal': 0,
#  'Netherlands': 4066,
#  'New Zealand': 14,
#  'Nicaragua': 2,
#  'Niger': 22,
#  'Nigeria': 28,
#  'North Macedonia': 56,
#  'Norway': 187,
#  'Oman': 8,
#  'Pakistan': 212,
#  'Panama': 141,
#  'Papua New Guinea': 0,
#  'Paraguay': 9,
#  'Peru': 530,
#  'Philippines': 446,
#  'Poland': 426,
#  'Portugal': 785,
#  'Qatar': 10,
#  'Romania': 524,
#  'Russia': 513,
#  'Rwanda': 0,
#  'Saint Kitts and Nevis': 0,
#  'Saint Lucia': 0,
#  'Saint Vincent and the Grenadines': 0,
#  'San Marino': 40,
#  'Sao Tome and Principe': 0,
#  'Saudi Arabia': 114,
#  'Senegal': 6,
#  'Serbia': 125,
#  'Seychelles': 0,
#  'Sierra Leone': 0,
#  'Singapore': 12,
#  'Slovakia': 14,
#  'Slovenia': 79,
#  'Somalia': 8,
#  'South Africa': 65,
#  'South Sudan': 0,
#  'Spain': 21717,
#  'Sri Lanka': 7,
#  'Sudan': 13,
#  'Suriname': 1,
#  'Sweden': 1937,
#  'Switzerland': 1509,
#  'Syria': 3,
#  'Taiwan*': 6,
#  'Tanzania': 10,
#  'Thailand': 49,
#  'Timor-Leste': 0,
#  'Togo': 6,
#  'Trinidad and Tobago': 8,
#  'Tunisia': 38,
#  'Turkey': 2376,
#  'US': 46583,
#  'Uganda': 0,
#  'Ukraine': 174,
#  'United Arab Emirates': 52,
#  'United_Kingdom': 18151,
#  'Uruguay': 12,
#  'Uzbekistan': 7,
#  'Venezuela': 10,
#  'Vietnam': 0,
#  'West Bank and Gaza': 4,
#  'Western Sahara': 0,
#  'Yemen': 0,
#  'Zambia': 3,
#  'Zimbabwe': 4,
#  'date': Timestamp('2020-04-22 00:00:00')}
